# %%
#@title Импорт библиотек.

# Фиксируем версии библиотек на 22.11.2023
# !pip  install  tiktoken==0.5.1
# !pip  install  langchain==0.0.339
# !pip  install  openai==1.3.4
# !pip  install  faiss-cpu==1.7.4
# !pip install gspread==3.4.2

from langchain.vectorstores import FAISS
from langchain.docstore.document import Document
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import MarkdownHeaderTextSplitter

import requests
import os
import re
import getpass
import openai
import tiktoken
from openai import OpenAI
import zipfile
from IPython import display
import timeit

import gspread                  # Импортируем API для работы с Google таблицами
from google.colab import auth   # Импортируем модуль для аутентификации
from google.auth import default # Импортируем модуль для работы с учетными данными

# Очистить экран.
display.clear_output()

# %%
#@title Ввод ключа к API OpenAI.

openai.api_key = getpass.getpass("Введите OpenAi API key:")
os.environ["OPENAI_API_KEY"] = openai.api_key
# Out:
# Введите OpenAi API key:··········

# %% [markdown]
# # Внутренности.

# %%
#@title Вспомогательные функции

def num_tokens_from_string(string: str) -> int:
    """Возвращает количество токенов в строке"""
    # Выбор кодировщика. `cl100k_base`используется для `gpt-4`, `gpt-3.5-turbo`, `text-embedding-ada-002`
    encoding = tiktoken.get_encoding("cl100k_base")
    # Разбивка строки на токены и подсчет из количества.
    num_tokens = len(encoding.encode(string))
    return num_tokens

def split_text(text, verbose=0):
    """ Функция разбивает текст на чанки. """
    # Шаблон MarkdownHeaderTextSplitter по которому будет делится переданный
    # текст в формате Markdown.
    headers_to_split_on = [ ("#", "Header 1"),
                            ("##", "Header 2"),
                            ("###", "Header 3")
                        ]
    # Создаем экземпляр спилиттера.
    markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
    # Получаем список чанков.
    source_chunks = markdown_splitter.split_text(text)

    # Обработка чанков.
    chank_count = len(source_chunks)
    for number, chank in enumerate(source_chunks):
        # Добавление информайии в чанк о его номере в базе.
        chank.page_content = f'Chank#{number}/{chank_count}. {chank.page_content}'
        # Вывод количества слов/токенов в фрагменте, если включен режим verbose.
        if verbose:
            count = num_tokens_from_string(chank.page_content)
            print(f"\nChank#{number}/{chank_count}. Tokens in text = {count}\n{'-' * 20}\n{insert_newlines(str(chank))}\n{'=' * 20}")

    # Возвращение списка фрагментов текста.
    return source_chunks

def create_embedding(data, verbose=0):
    """Функция преобразует текстовую Базу знаний в векторную."""
    # Разбивка текста на чанки.
    source_chunks = []
    source_chunks = split_text(text=data, verbose=verbose)

    # Создание векторной Базы знаний на основе чанков.
    search_index = FAISS.from_documents(source_chunks, OpenAIEmbeddings(), )
    # Подсчет общего количества токенов во всех чанках.
    count_token = num_tokens_from_string(' '.join([x.page_content for x in source_chunks]))
    # Печать сводной информации по созданию векторной Базы знаний.
    print('\n==================== ')
    print('Количество токенов в документе :', count_token)
    # Стоимость эмбэндинга согласно прайса на 22.11.2023 - 0,0001/1К токенов.
    # https://openai.com/pricing#language-models
    print('ЦЕНА запроса:', 0.0001*(count_token/1000), ' $')
    return search_index

def load_file(url: str):
    """ Функция загрузки документа по url как текст."""
    try:
        response = requests.get(url) # Получение документа по url.
        response.raise_for_status()  # Проверка ответа и если была ошибка - формирование исключения.
        return response.text
    except Exception as e:
        print(e)

def load_search_indexes(url: str, verbose=0):
    """Функция загружает текстовую Базу знаний и преобразует ее в векторную."""
    try:
        return create_embedding(load_file(url), verbose=verbose)
    except Exception as e:
        print(e)

def insert_newlines(text: str, max_len: int = 120) -> str:
    """ Функция форматирует переданный текст по длине
    для лучшего восприятия на экране."""
    words = text.split()
    lines = []
    current_line = ""
    for word in words:
        if len(current_line + " " + word) > max_len:
            lines.append(current_line)
            current_line = ""
        current_line += " " + word
    lines.append(current_line)
    return "\n".join(lines)

def answer_index(model, system, topic, query, search_index, temp = 1, verbose_documents = 0,  verbose_price = 0, top_documents = 3):
    """ Основная функция которая формирует запрос и получает ответ от OpenAI по заданному вопросу
    на основе векторной Базы знаний. """

    # Выбор варианта вопроса. Если есть query то вопрос задан из группового запроса.
    question = query["question"] if bool(query) else topic
    # Выборка релевантных чанков.
    docs = search_index.similarity_search(question, k=top_documents)

    message_content = ""            # Контекст для GPT.
    message_content_display = ""    # Контекст для вывода на экран.
    for i, doc in enumerate(docs):
        # Формирование контекста для запроса GPT и показа на экран отобранных чанков.
        message_content = message_content + f'Отрывок документа №{i+1}:{doc.page_content}'
        message_content_display = message_content_display + f'\nОтрывок документа №{i+1}\n-----------------------\n{insert_newlines(doc.page_content)}\n'
        # Сбор информации для группого запроса.
        if bool(query):
            link = re.search(r'\[(.*?)\]', doc.metadata['Header 1']).group(1)
            query[f"chank_{i+1}"] = f"{doc.page_content}. \n--------\n{link.strip()}"

    # Вывод на экран отобранных чанков.
    if (verbose_documents):
        print(message_content_display)

    # Отправка запроса к Open AI.
    completion = OpenAI().chat.completions.create(
        model = model[0],
        messages = [
            {"role": "system", "content": system + f"{message_content}"},
            {"role": "user", "content": question}
        ],
        temperature=temp
    )

    # Подсчет токенов и стоимости.
    prompt_tokens = completion.usage.prompt_tokens
    total_tokens = completion.usage.total_tokens
    price_promt_tokens = prompt_tokens * model[1]/1000
    price_answer_tokens = (total_tokens - prompt_tokens) * model[2]/1000
    price_total_token = price_promt_tokens + price_answer_tokens
    # Сбор информации для группого запроса.
    if bool(query):
        query["price_query"] = price_total_token
        query["price_question"] = price_promt_tokens
        query["price_answer"] = price_answer_tokens
        query["token_query"] = total_tokens
        query["token_question"] = prompt_tokens
        query["token_answer"] = total_tokens - prompt_tokens
    # Вывод на экран стоимости запроса.
    if (verbose_price):
        print('\n======================================================= ')
        print(f'{prompt_tokens} токенов использовано на вопрос. Цена: {round(price_promt_tokens, 6)} $.')
        print(f'{total_tokens - prompt_tokens} токенов использовано на ответ.  Цена: {round(price_answer_tokens, 6)} $.')
        print(f'{total_tokens} токенов использовано всего.     Цена: {round(price_total_token, 6)} $')
        print('======================================================= ')

    # Ответ OpenAI.
    return completion.choices[0].message.content

# %%
#@title Вспомогательные функции для загрузки Базы знаний.

def load_bd_text(url: str, verbose=0):
    """ Функция загружает текстовую Базу знаний и
        преобразует ее в векторную."""
    response = requests.get(url) # Получение документа по url.
    response.raise_for_status()  # Проверка ответа и если была ошибка - формирование исключения.
    return create_embedding(response.text, verbose=verbose)

def load_bd_vect(url: str, verbose=0):
    """ Функция загружает векторную Базу знаний."""
    name_bd = 'federallab_bd_index.zip'
    # Скачивание архива Базы знаний
    response = requests.get(url) # Получение документа по url.
    response.raise_for_status()  # Проверка ответа и если была ошибка - формирование исключения.
    # Сохранение архива.
    with open(name_bd, 'wb') as file:
        file.write(response.content)
    # Разархивирование Базы знаний.
    with zipfile.ZipFile(name_bd, 'r') as zip:
        zip.extractall()
    # Загрузка векторной Базы знаний.
    federallab_bd = FAISS.load_local(f'federallab_bd_index', OpenAIEmbeddings())
    return federallab_bd

def load_bd (url_vect: str, url_text: str, verbose=0):
    """ Функция организует очередность загрузки Базы знаний.
        Сначала идет загрузка векторной базы, если она не загружается,
        то загружается база в текстовом формате и потом преобразуется в векторную."""
    try:
        federallab_bd = load_bd_vect(url_vect, verbose)
        print("Загрузка векторной Базы знаний выполнена успешно.")
        return federallab_bd
    except Exception as e:
        print("По указанной ссылке векторной Базы знаний нет.")
        print(e)
        print("\nИдет загрузка текстовой Базы знаний...")
        try:
            federallab_bd = load_bd_text(url_text, verbose)
            print("\nЗагрузка текстовой Базы знаний выполнена успешно.")
            return federallab_bd
        except Exception as e:
            print("\nПо указанной ссылке текстовой Базы знаний нет.")
            print(e)
            print("\nОшибка загрузки!!")

# %%
#@title Загрузка Базы знаний..

# Сылка на Базу знаний на Github в текстовом формате.
link_bd_text = "https://raw.githubusercontent.com/terrainternship/GPT_labsud/main/Datadase/LabSudDB_v1.md"
# Сылка на Базу знаний на Github в векторном формате.
link_bd_vect = '-https://github.com/terrainternship/GPT_labsud/raw/main/federallab_bd_index.zip'
# Показывать полученные чанки только при загрузке Базы знаний в текстовом формате.
verbose_bd = 1

# Загрузка Базы знаний.
federallab_bd_index = load_bd(link_bd_vect, link_bd_text, verbose=verbose_bd )
# Out:
# По указанной ссылке векторной Базы знаний нет.
# No connection adapters were found for '-https://github.com/terrainternship/GPT_labsud/raw/main/federallab_bd_index.zip'
#
# Идет загрузка текстовой Базы знаний...
#
# Chank#0/215. Tokens in text = 283
# --------------------
#  page_content='Chank#0/215. Экспертиза границ участков. Когда требуется экспертиза границ участков. \nЭкспертиза может
#  потребоваться в нескольких ситуациях: \nпри выявлении ранее допущенных ошибок;\nпри спорных вопросах между
#  соседями;\nпри несанкционированном самовольном изменении границ;\nпри делении участка на несколько собственников.
#  \nПоскольку процедура экспертизы требует проведения сложных измерительных и вычислительных работ, производится она в
#  строго определенном законом порядке и по регламенту. Проведение процедуры может производить организация, которая имеет
#  лицензию на данный вид деятельности. Топографическую съемку производит сертифицированный специалист.' metadata={'Header
#  1': 'Экспертиза границ участков [
#  https://federallab.ru/uslugi-ekspertizyi/zemleustroitelnaya-ekspertiza/ekspertiza-granicz-uchastkov/ ]', 'Header 2':
#  'Когда требуется экспертиза границ участков'}
# ====================
#
# Chank#1/215. Tokens in text = 579
# --------------------
#  page_content='Chank#1/215. Экспертиза границ участков. Когда требуется экспертиза границ участков. Варианты проведения
#  экспертизы уточнения границ участков. \nПроцедура проводится по разным регламентам: \nДосудебная. Экспертиза подобного
#  типа проводится до обращения сторонами в судебный орган и производится при обращении обеих сторон в соответствующий
#  орган, который уполномочен произвести процедуру;\nСудебная. Межевание производится при контроле судебными органами
#  после вынесения постановления. Процесс контролируется судебными органами, которые устанавливают временные рамки и
#  осуществляют контроль. В процессе проведения мероприятия на объекте присутствует представитель судебного органа.
#  \nВторой вариант проведения межевания требует составления отчетности и предоставления копий результатов проведения
#  исследований в судебную инстанцию. \nЧтобы определить спорные границы между участками, потребуется длительная и
#  кропотливая работа. Сюда могут включаться не только геодезические работы. Проводятся исследования по историческому
#  установлению границ и сопоставлению их фактическими. \nЭкспертизу определения границ должны проводить уполномоченные
#  организации, поскольку обнаружение в последствие ошибочных данных могут потребовать вторичного проведения процедуры,
#  они определяют также стоимость на экспертизу границ участка. \nНаша компания специализируется в данной сфере и готова
#  оказать вам любую поддержку.' metadata={'Header 1': 'Экспертиза границ участков [
#  https://federallab.ru/uslugi-ekspertizyi/zemleustroitelnaya-ekspertiza/ekspertiza-granicz-uchastkov/ ]', 'Header 2':
#  'Когда требуется экспертиза границ участков', 'Header 3': 'Варианты проведения экспертизы уточнения границ участков'}
# ====================
#
# Chank#2/215. Tokens in text = 695
# --------------------
#  page_content='Chank#2/215. Бухгалтерская экспертиза. \nОсновные документы проверки при бухгалтерской экспертизе \n01
#  первичные документы – платёжные поручения, приходные, расходные кассовые ордера, накладные на отпуск и получение
#  товара, товарно-транспортные накладные, акты выполненных работ, платёжные, расчётные ведомости, квитанции, чеки и пр.;
#  \n02 документы справочно-технического характера о котировках ценных бумаг, ставках рефинансирования, курсах валют,
#  индексах инфляции и пр. \n03 материалы инвентаризации – описи наличия товара, сличительные ведомости, отчёты
#  материально-ответственных лиц, акты сверки задолженностей и пр.; \n04 калькуляции – расчёт себестоимости продукции,
#  смета предстоящих расходов, финансовые и бизнес-планы, технико - экономическое обоснование заключения сделки или
#  получения кредита и пр.; \n05 организационно-распорядительные – приказы, регламентирующие производственную, финансовую
#  и хозяйственную деятельность, в том числе учётную политику хозяйствующего \n06 отчётность бухгалтерская и налоговая –
#  бухгалтерский баланс и приложение к нему, налоговые декларации, финансовые отчёты, отчёт о движении капитала, отчёт о
#  прибылях и убытках, расчёты налогов и других обязательных платежей и взносов и пр.; \n07 субъекта, распоряжения,
#  поручения; \n08 различные виды договоров, меморандумов, контрактов; \n09 бухгалтерские регистры – главные книги,
#  журналы-ордера, оборотные ведомости, карточки аналитического учёта; \n10 ценные бумаги (акции, векселя, облигации и
#  пр.).' metadata={'Header 1': 'Бухгалтерская экспертиза [
#  https://federallab.ru/uslugi-ekspertizyi/buxgalterskaya-ekspertiza/ ]'}
# ====================
#
# Chank#3/215. Tokens in text = 1501
# --------------------
#  page_content='Chank#3/215. Бухгалтерская экспертиза. Этапы проведения бухгалтерской экспертизы \n01 Выявление фактов
#  (признаков) искажения учетных данных специфическими для бухгалтерского учета приемами и диагностика обнаруженных
#  искажений, определение степени их влияния на показатели хозяйственной деятельности. \n06 Исследование показателей
#  финансового состояния и финансово-экономической деятельности хозяйствующего субъекта, в том числе платежеспособности,
#  финансовой устойчивости, ликвидности и др. \n02 Исследование признаков и способов искажения данных о финансовых
#  показателях, влияющих на финансовый результат и расчеты по обязательствам хозяйствующего субъекта. \n07 Реконструкция
#  (воссоздание) отсутствующих либо искаженных записей на основе более поздних или предыдущих закономерных связей. \n03
#  Характеристика динамики финансового состояния предприятия и анализ факторов, вызвавших её негативные изменениям. \n08
#  Установление соответствия данных аналитического и синтетического учета данным первичных документов, отчётности.\n04
#  Определение экономической обоснованности финансовых показателей предприятия в случае искажения данных о доходах и
#  расходах. \n09 Установление соответствия отражения совершенных операций правилам ведения бухгалтерского учета. \n05
#  Установление тождества или различия черновых записей данным официального бухгалтерского учета. \n10 Степень
#  обеспеченности предприятия оборотными средствами. \nПри производстве бухгалтерской экспертизы могут решаться следующие
#  задачи: \nВыявление фактов (признаков) искажения учетных данных специфическими для бухгалтерского учета приемами и
#  диагностика обнаруженных искажений, определение степени их влияния на показатели хозяйственной
#  деятельности.\nУстановление тождества или различия черновых записей данным официального бухгалтерского
#  учета.\nУстановление соответствия данных аналитического и синтетического учета данным первичных документов,
#  отчётности.\nРеконструкция (воссоздание) отсутствующих либо искаженных записей на основе более поздних или предыдущих
#  закономерных связей.\nУстановление соответствия отражения совершенных операций правилам ведения бухгалтерского
#  учета.\nИсследование показателей финансового состояния и финансово-экономической деятельности хозяйствующего субъекта,
#  в том числе платежеспособности, финансовой устойчивости, ликвидности и др.\nИсследование признаков и способов искажения
#  данных о финансовых показателях, влияющих на финансовый результат и расчеты по обязательствам хозяйствующего
#  субъекта.\nХарактеристика динамики финансового состояния предприятия и анализ факторов, вызвавших её негативные
#  изменения.\nОпределение экономической обоснованности финансовых показателей предприятия в случае искажения данных о
#  доходах и расходах.\nСтепень обеспеченности предприятия оборотными средствами.\nПричины образования дебиторской и
#  кредиторской задолженности. \nТак как проведение бухгалтерской экспертизы осуществляется в двух случаях: по решению
#  суда или заинтересованным лицом по договору, то и сроки устанавливаются разные. \nВ первом случае сроки устанавливаются
#  в индивидуальном порядке, их закрепляет постановление. Поэтому выходить за их рамки эксперт не имеет права. \nВо втором
#  случае сроки определяет руководитель компании, которая проводит бухгалтерскую экспертизу. Как правило, на это
#  мероприятие отводится около 20 дней. Тем не менее заказчик может попросить о сокращении сроков. Но отражаться на
#  качестве выполняемой работы это не должно.' metadata={'Header 1': 'Бухгалтерская экспертиза [
#  https://federallab.ru/uslugi-ekspertizyi/buxgalterskaya-ekspertiza/ ]', 'Header 2': 'Этапы проведения бухгалтерской
#  экспертизы'}
# ====================
#
# Chank#4/215. Tokens in text = 264
# --------------------
#  page_content='Chank#4/215. Экспертиза качества строительства. \nОт того, были ли соблюдены технологии, правила и нормы
#  строительства, насколько качественными оказались материалы, и насколько ответственно подошли к работе подрядчики,
#  зависит срок службы здания, безопасность людей и имущества, которые в нем находятся. Это касается как самих
#  строительных работ (возведения зданий, сооружений, объектов инфраструктуры), так и дополнительных мероприятий - монтажа
#  инженерных систем, отделки, реконструкции и т.д. Если после выполнения работ у клиента строительной компании возникли
#  вопросы к качеству результата, он может воспользоваться услугами независимого эксперта.' metadata={'Header 1':
#  'Экспертиза качества строительства [
#  https://federallab.ru/uslugi-ekspertizyi/stroitelno-texnicheskaya-ekspertiza/ekspertiza-kachestva-stroitelstva/ ]',
#  'Header 2': 'Экспертиза качества строительства'}
# ====================
#
# Chank#5/215. Tokens in text = 995
# --------------------
#  page_content='Chank#5/215. Экспертиза качества строительства. В каких случаях может потребоваться строительная
#  экспертиза?. \nСитуаций, которые требуют участия независимого эксперта, достаточно много. Клиентами Федеральной
#  лаборатории судебной экспертизы могут быть дольщики, владельцы коммерческих или жилых площадей, арендаторы, лица
#  (физические и юридические), заказавшие реконструкцию или отделку, а также сами строительные компании (подрядчики или
#  субподрядчики). \nЭксперт поможет разобраться в следующих ситуациях: \n•\xa0При неудовлетворительном, по мнению
#  клиента, качестве услуг и материалов. \n•\xa0При подозрении на завышенный бюджет строительства или ремонта. \n•\xa0При
#  подозрении на использование дешевых аналогов вместо дорогих материалов, которые были оплачены. \n•\xa0При обнаружении
#  ошибок после подписания акта приема-передачи. \n•\xa0При задержке оплаты подрядчикам со стороны клиента. \n•\xa0При
#  начале судебного разбирательства, касающегося качества работ и материалов, полноты выполнения услуг, прописанных в
#  договоре. \nПроверив качество строительных, отделочных или монтажных работ и материалов, закончив оценку физического
#  износа здания (если дефекты были выявлены через несколько лет после сдачи объекта), эксперт составит объективное
#  заключение, которое можно будет использовать в суде и при досудебном урегулировании споров. Специалист ориентируется на
#  требования закона и правила и нормы, закрепленные в российских технических регламентах. \n•\xa0В рамках экспертизы
#  сотрудник ФЛСЭ определит: \n•\xa0качество материалов, правильность их применения; \n•\xa0количество и масштаб дефектов
#  (от трещины до разрушения фундамента); \n•\xa0причины выявленных дефектов; \n•\xa0соответствие результата (строения,
#  элемента здания, отделки) параметрам, закрепленным в проекте, смете, договоре; \n•\xa0причины нарушения технологий;
#  \n•\xa0подлинность заявленных материалов. \nПолучив экспертное заключение, вы сможете защитить свои интересы в споре с
#  недобросовестным исполнителем или заказчиком, доказать, что дефекты присутствуют, и качество работ не соответствует
#  тому, что было заявлено, или что весь объем был выполнен на должном уровне. Лаборатория судебной экспертизы ФЛСЭ.,
#  действует исключительно в рамках закона, а заключения, составленные нашими экспертами, имеют силу в суде.'
#  metadata={'Header 1': 'Экспертиза качества строительства [
#  https://federallab.ru/uslugi-ekspertizyi/stroitelno-texnicheskaya-ekspertiza/ekspertiza-kachestva-stroitelstva/ ]',
#  'Header 2': 'В каких случаях может потребоваться строительная экспертиза?'}
# ====================
#
# Chank#6/215. Tokens in text = 263
# --------------------
#  page_content='Chank#6/215. Экспертиза межевого дела. Процесс межевания. \nВесь процесс межевания проходит в несколько
#  этапов: \nподготовительный этап заключается в поиске исполнителя и заключении договора;\nсоставление плана
#  участка;\nоповещение владельцев граничащих участков о проведении межевания. Это необходимо для того, чтобы в
#  последствие не возникло разногласий по положению границ;\nнепосредственно само межевание, которое производится с
#  использованием геодезических приборов;\nсоставление нового плана и сверка его с документальным;\nвыдача межевого дела
#  собственнику;\nподача документов в регистрационный орган для составления паспорта участка.' metadata={'Header 1':
#  'Экспертиза межевого дела [
#  https://federallab.ru/uslugi-ekspertizyi/zemleustroitelnaya-ekspertiza/ekspertiza-mezhevogo-dela/ ]', 'Header 2':
#  'Процесс межевания'}
# ====================
#
# Chank#7/215. Tokens in text = 546
# --------------------
#  page_content='Chank#7/215. Экспертиза межевого дела. Процесс межевания. В каких ситуациях требуется проведение
#  экспертизы. \nЭкспертиза межевого дела может производиться при возникновении спорных вопросов по определению границ
#  участка. Это могут быть различные ситуации: \nнесогласие собственников граничащих участков с результатами проведенного
#  межевания;\nутрата паспорта или межевого дела;\nвыделение доли участка или его раздел на несколько собственников.
#  \nЭкспертиза может производится двумя путями: \nв досудебном порядке. Претензии выдвигаются собственниками друг к
#  другу, они согласованно заказывают проведение экспертизы. Срок ее выполнения от пары недель до нескольких
#  месяцев;\nпосле вынесения судебного постановления. Процедура проводится в пределах четко установленного судом
#  промежутка времени с составлением необходимых бумаг. Данный процесс более дорогостоящий для инициирующей его стороны,
#  поскольку возникает необходимость оплаты судебных затрат. \nПри заказе экспертной процедуры необходимо обращаться в
#  компетентную организацию, которая имеет соответствующие лицензии и сертификационные удостоверения. В противном случае,
#  в случае возникновения спорных взаимодействий соседей или при отчуждении потребуется повторное проведение межевания.
#  \nНаши специалисты готовы помочь вам в любом вопросе.' metadata={'Header 1': 'Экспертиза межевого дела [
#  https://federallab.ru/uslugi-ekspertizyi/zemleustroitelnaya-ekspertiza/ekspertiza-mezhevogo-dela/ ]', 'Header 2':
#  'Процесс межевания', 'Header 3': 'В каких ситуациях требуется проведение экспертизы'}
# ====================
#
# Chank#8/215. Tokens in text = 773
# --------------------
#  page_content='Chank#8/215. Экспертиза бытовой техники. \nКоличество производственных дефектов, обнаруженных в бытовой
#  технике, неуклонно растет. Это приводит к увеличению числа споров между продавцами и покупателями. Доказать, что дефект
#  появился по вине производителя, практически невозможно без проведения экспертизы бытовой техники. Инициатором
#  проведения может выступать покупатель или следственные органы. \nЕсли продавец отказал в гарантийном ремонте техники,
#  возврате денег, обмене товара и вообще не склонен к решению вопросов с дефектным товаром, то следует поступить
#  следующим образом: \nСамостоятельно провести экспертизу в нашей компании;\nПодать претензию продавцу, приложив
#  документы с заключением;\nВ случае отказа – обратиться в суд. \nКак правило, вопрос двигается с «мертвой точки» сразу
#  после подачи претензии с результатами независимой экспертизы. Это доказательство вашей правоты, которое непременно
#  будет учитываться в суде. Большинству продавцов не нужны судебные разбирательства, и они идут на компромиссное решение.
#  Но есть ряд компаний, которые предпочитают решать такие вопросы только через суд. \nСуществуют ситуации, в которых
#  потребитель и производитель невиновны в возникновении неисправности, например, когда поломка произошла из-за
#  некачественных услуг электроснабжения. Для выявления причины неисправности требуется ряд исследований и тестов на
#  специальном оборудовании. \nДаже учитывая, что стоимость экспертизы может возмещаться виновной стороной, мы не завышаем
#  ее стоимость. Мы понимаем, что изначально деньги берутся у инициатора процедуры и только через некоторое время
#  возвращаются виновником. Время проведения зависит от сложности выявления дефекта – это могут быть микротрещины в плате
#  электроники или очевидное короткое замыкание, в любом случае она будет выявлена.' metadata={'Header 1': 'Экспертиза
#  бытовой техники [ https://federallab.ru/uslugi-ekspertizyi/tovarnaya-ekspertiza/ekspertiza-byitovoj-texniki/ ]',
#  'Header 2': 'Экспертиза бытовой техники'}
# ====================
#
# Chank#9/215. Tokens in text = 212
# --------------------
#  page_content='Chank#9/215. Экспертиза технического состояния ТС. Какие элементы ТС могут быть подвергуты экспертизе
#  технического состояния ТС. \nВ рамках экспертизы технического состояния ТС может быть проведена:\nэкспертиза двигателя
#  автомобиля и его мощности;\nэкспертиза кузова;\nэкспертиза коробки передач;\nэкспертиза подвески;\nэкспертиза
#  шасси;\nэкспертиза бампера;\nэкспертиза приборов;\nэкспертиза прочих узлов и агрегатов.' metadata={'Header 1':
#  'Экспертиза технического состояния ТС [
#  https://federallab.ru/uslugi-ekspertizyi/avtotexnicheskaya-ekspertiza/ekspertiza-texnicheskogo-sostoyaniya-ts/ ]',
#  'Header 2': 'Какие элементы ТС могут быть подвергуты экспертизе технического состояния ТС.'}
# ====================
#
# Chank#10/215. Tokens in text = 181
# --------------------
#  page_content='Chank#10/215. Экспертиза технического состояния ТС. Направления экспертизы технического состояния ТС
#  \nЭкспертиза технического состояния транспортных средств выполняется по следующим основным направлениям:\n1. В связи с
#  совершенным дорожно-транспортным происшествием.\n2. При возникновении сомнений в качестве транспортного средства.\n3.
#  Выявлении дефектов в процессе его эксплуатации.' metadata={'Header 1': 'Экспертиза технического состояния ТС [
#  https://federallab.ru/uslugi-ekspertizyi/avtotexnicheskaya-ekspertiza/ekspertiza-texnicheskogo-sostoyaniya-ts/ ]',
#  'Header 2': 'Направления экспертизы технического состояния ТС.'}
# ====================
#
# Chank#11/215. Tokens in text = 892
# --------------------
#  page_content='Chank#11/215. Экспертиза технического состояния ТС. Что позволяет определить экспертиза технического
#  состояния ТС. \nПроведение экспертизы технического состояния транспортных средств позволяет:\nопределить наличие или
#  отсутствие неисправности, поломки, дефекта в обследуемом транспортном средстве (автомобиле);\nопределить, является ли
#  выявленная неисправность, поломка или дефект в обследуемом транспортном средстве (авто) приобретенной в ходе
#  неправильной эксплуатации автомашины, либо же данная неисправность (дефект, недостаток) имеет заводской
#  характер;\nопределить время (момент) возникновения неисправности, поломки или дефекта относительно ДТП (до или
#  после);\nопределить причину возникновения неисправности, поломки или дефекта относительно характера возникновения
#  (заводской дефект транспортного средства или дефект в процессе эксплуатации автомобиля);\nопределить причину
#  возникновения неисправности, поломки или дефекта относительно причины возникновения (с чем именно произошло
#  столкновение);\nустановить в период какого технологического заводского цикла дефекты могли возникнуть (в момент
#  проектирования или конструирования автомобиля, либо в момент литья узлов и деталей, либо в момент некачественной или
#  неправильной сборки узлов и агрегатов автомашины) если неисправность, поломка или дефект, имеет ярко выраженное
#  заводское происхождение\nустановить в чем конкретно выражена неправильная эксплуатация транспортного средства, если
#  неисправности, поломки или дефекты, являются приобретенными в ходе неправильной эксплуатации транспортного
#  средства\nустановить причинно-следственные связи между неисправностью и ДТП, а также обстоятельствами, способствующими
#  возникновению неисправностей\nустановить техническую возможность предотвращения ДТП (наезда, столкновения, потери
#  устойчивости и т.п.) при определенном техническом состоянии ТС, их отдельных узлов, механизмов, систем, агрегатов, в
#  момент ДТП\nустановить обстоятельства, связанные с техническим состоянием ТС, которые способствовали или могли
#  способствовать возникновению ДТП.' metadata={'Header 1': 'Экспертиза технического состояния ТС [
#  https://federallab.ru/uslugi-ekspertizyi/avtotexnicheskaya-ekspertiza/ekspertiza-texnicheskogo-sostoyaniya-ts/ ]',
#  'Header 2': 'Что позволяет определить экспертиза технического состояния ТС.'}
# ====================
#
# Chank#12/215. Tokens in text = 1380
# --------------------
#  page_content='Chank#12/215. Экспертиза обстоятельств ДТП и следов ТС.\nНезависимая автотехническая экспертиза
#  \nПредметом исследования при проведении экспертизы обстоятельств ДТП являются дорожно-транспортные ситуации (ДТС),
#  параметры движения ТС, иных объектов и пешеходов в процессе ДТП, а также действия и возможности водителей. При
#  транспортно-трасологической экспертизе исследованию подлежат следы различных видов транспорта (от колес, гусениц,
#  выступающих частей ТС, частиц ТС) и механизмы их образования. \nОбъектами экспертизы могут быть: дорожное покрытие,
#  транспортные средства, одежда и тело человека, дорожные ограждения и знаки, придорожные постройки. \nПримерные вопросы
#  на разрешение эксперта-трасолога: \nОпределить механизм столкновения транспортных средств, представленных на
#  транспортно-трасологическую экспертизу (удар, скольжение, волочение и пр.)?\nОпределить, имело ли место столкновение
#  представленных на исследование ТС, исходя из характера и локализации повреждений на данных ТС?\nОпределить
#  последовательность возникновения повреждений (следов) при столкновении транспортного средства о преграду?\nОпределить
#  угол взаимного расположения ТС в момент их первоначального контакта?\nОпределить, в каком направлении двигалось
#  транспортное средство в момент наезда?\nОпределить траекторию и характер движения транспортных средств?\nОпределить,
#  где, относительно границ проезжей части, находится место столкновения (место наезда)?\nОпределить расположение
#  транспортных средств и препятствий в момент удара (или в другие заданные моменты времени)?\nОпределить, взаимное
#  расположение транспортных средств в момент столкновения?\nОпределить, находилось в движении или было неподвижно ТС в
#  момент столкновения с ним другого ТС?\nОпределить, какой деталью (частью) транспортного средства оставлены
#  следы?\nОпределить, каким видам транспорта, судя по следам, присущи такие детали (такого размера, формы,
#  локализации)?\nОпределить, транспортом какого типа (легковым, грузовым, гусеничным и т.д.) оставлены
#  следы?\nОпределить, какой частью транспортного средства нанесены повреждения?\nИсследование следов шин транспортных
#  средств\nОпределить, модель шины, которой был оставлен след, слепок которого представлен на транспортно-трасологическую
#  экспертизу?\nОпределить, к какому типу (модели или марки) относится транспортное средство, оставившее следы на месте
#  ДТП ?\nОпределить, в каком направлении от места ДТП двигалось данное ТС, оставившее следы колес на том или ином участке
#  дороги?\nОпределить, не могли ли данные следы быть оставлены такими-то колесами (передними, задними, правыми, левыми)
#  определенного транспортного средства?\nОпределить, являются ли данные следы результатом воздействия шин транспортного
#  средства?\nОпределить, какие дефекты имеют шины, оставившие следы на месте ДТП?\nОпределить, отличительные признаки
#  шин, отобразившиеся в следах (например дефекты, степень износа протектора, неравномерный износ протектора вследствие
#  неправильной регулировки углов установки или дисбаланса колес, пробои и порезы, вздутие протектора и др.)?\nОпределить,
#  грузовым или легковым автомобилем были оставлены следы?' metadata={'Header 1': 'Экспертиза обстоятельств ДТП и следов
#  ТС [ https://federallab.ru/uslugi-ekspertizyi/avtotexnicheskaya-ekspertiza/ekspertiza-obstoyatelstv-dtp-i-sledov-ts/
#  ]'}
# ====================
#
# Chank#13/215. Tokens in text = 728
# --------------------
#  page_content='Chank#13/215. Что делать, если вы попали в ДТП.\nНезависимая автотехническая экспертиза \nДействия
#  водителя, попавшего в ДТП, в первую очередь регламентируются пунктом 2.5 Постановления Правительства РФ № 1090 от
#  23.10.1993 (с изм. и доп.) «О Правилах дорожного движения», который обязывает водителей, причастных к ДТП: \nНемедленно
#  остановить (не трогать с места) транспортное средство, включить аварийную сигнализацию и выставить знак аварийной
#  остановки\nПринять меры для оказания первой помощи пострадавшим\nОсвободить проезжую часть, если движение других
#  транспортных средств невозможно \nДо приезда ГИБДД также рекомендуется зафиксировать положение транспортных средств и
#  все повреждения на вашем автомобиле на фотоаппарат или камеру мобильного телефона. В дальнейшем на основании
#  первоначально составленных сотрудником ГИБДД документов - протокола осмотра места происшествия, справки о ДПТ,
#  протокола о техническом состоянии транспортных средств, схемы ДПТ, объяснения участников ДПТ, показания свидетелей и
#  т.д. органы ГИБДД устанавливают связь между действиями водителей и наступившими последствиями. Поэтому, перед
#  подписанием каких-либо документов внимательно ознакомьтесь с их содержанием и по возможности сделайте копию или
#  фотофиксацию. \nВ сложных ситуациях, связанных с дорожно-транспортными происшествиями, или при купле-продаже
#  автомобилей часто требуется профессиональная автотехническая экспертиза. Специалисты ФЛСЭ помогут разрешить спорные
#  вопросы путем проведения экспертной оценки состояния автомобиля и работ, необходимых для его восстановления после
#  участия в ДТП.' metadata={'Header 1': 'Что делать, если вы попали в ДТП [
#  https://federallab.ru/uslugi-ekspertizyi/avtotexnicheskaya-ekspertiza/chto-delat-esli-vyi-popali-v-dtp/ ]'}
# ====================
#
# Chank#14/215. Tokens in text = 235
# --------------------
#  page_content='Chank#14/215. Автотовароведческая экспертиза. \nАвтотовароведческая экспертиза сочетает в себе два вида
#  экспертиз: товароведческую и автотехническую. Такой вид экспертизы дает возможность получить ответы на вопросы
#  относительно соответствия качества автомобиля как товара, его узлов и агрегатов данным, указанным в договоре
#  купли-продажи, а также условиям безопасности эксплуатации. \nАвтотовароведческая экспертиза часто по сути схожа с
#  экспертизой технического состояния транспортных средств.' metadata={'Header 1': 'Автотовароведческая экспертиза [
#  https://federallab.ru/uslugi-ekspertizyi/avtotexnicheskaya-ekspertiza/avtotovarovedcheskaya-ekspertiza/ ]'}
# ====================
#
# Chank#15/215. Tokens in text = 605
# --------------------
#  page_content='Chank#15/215. Автотовароведческая экспертиза. Вопросы в рамках автотовароведческой экспертизы. \n–
#  Установление наличия или отсутствия отклонений от нормального функционирования или состояния транспортного средства,
#  соответствующего заявленному в договоре купли-продажи, условиях эксплуатации и т.п.\n– В случае выявления отклонений –
#  определение причин, обусловивших их, а именно характера возникновения дефектов: производственного или
#  эксплуатационного. При этом исследуется причинно-следственная взаимосвязь между неисправностью и условиями эксплуатации
#  \nАвтотовароведческая экспертиза нередко требует применения специального оборудования, лабораторных исследований
#  материалов, а также разборных работ транспортного средства при исследовании внутренних узлов и агрегатов. Экспертами
#  ФЛСЭ осуществляется весь спектр необходимых этапов исследования с применением требуемых приборов, которые проходят
#  регулярную поверку. Приборные обследования проводятся как при выездном характере экспертизы, так и в помещениях ФЛСЭ
#  при оформлении протокола изъятия анализируемого узла или агрегата. \nПри оформлении заключений эксперта прикладываются
#  подробные фотоматериалы следующего вида (комментарии к фото опущены): \nИсследование излома опорной части рамы заднего
#  левого колеса \nИсследование цилиндра телескопирования автомобильного крана' metadata={'Header 1': 'Автотовароведческая
#  экспертиза [ https://federallab.ru/uslugi-ekspertizyi/avtotexnicheskaya-ekspertiza/avtotovarovedcheskaya-ekspertiza/
#  ]', 'Header 3': 'Вопросы в рамках автотовароведческой экспертизы'}
# ====================
#
# Chank#16/215. Tokens in text = 596
# --------------------
#  page_content='Chank#16/215. Почерковедческая экспертиза. \nОсновные виды услуг \nОбнаружение признаков необычности
#  выполнения в исследуемых почерковых объектах, в том числе, признаков «атаксии» - старческих изменений письма
#  \nУстановление конкретного исполнителя текста (экспертиза подписи) \nВыявление признаков применения технических средств
#  и предварительной технической подготовки при выполнении подписей и рукописного текста \nУстановление первоначального
#  содержания записи \nУстановление первичности исполнения подписи, печатного текста, оттиска печати при пересечении
#  штрихов \nПочерковедческая экспертиза - что позволяет выявить \nПочерковедческая экспертиза в Самаре может назначаться
#  в рамках расследования или быть проведена по желанию частного лица в досудебном порядке. В ее состав могут входить
#  исследования, которые делятся на идентификационные и неидентификационные. Первые проводят, когда необходимо выявить
#  следующие факторы: \n- все ли фрагменты текста выполнены одним лицом;\n- принадлежат ли одному исполнителю несколько
#  разных документов;\n- написан (подписан) ли данный текст конкретным лицом. \nПри помощи неидентификационных
#  исследований можно определить следующее: \n- в каком состоянии был исполнитель (алкогольное, наркотическое
#  воздействие);\n- пол человека, написавшего текст;\n- необычность обстановки при написании (неудобная поза, болезнь и т.
#  д.);\n- возрастная группа исполнителя;\n- одновременно ли выполнены все фрагменты текста.' metadata={'Header 1':
#  'Почерковедческая экспертиза [ https://federallab.ru/uslugi-ekspertizyi/podcherkovedcheskaya-ekspertiza/ ]'}
# ====================
#
# Chank#17/215. Tokens in text = 511
# --------------------
#  page_content='Chank#17/215. Оценка бизнеса.\nОценка бизнеса целиком или акций, пакетов акций, долей в уставном капитале
#  может производиться в целях дальнейшей продажи (выкупа у миноритарных акционеров), реструктуризации (слиянии,
#  присоедини, разделении), раздела собственности, обоснования инвестиционных проектов, обеспечения при кредитовании и
#  т.д. В большинстве случаев оценка производится на одну из дат подготовки бухгалтерской (финансовой) отчетности. Для
#  определения стоимости услуг по оценке и сроков проведения работ необходимо предоставление следующего минимального
#  пакета документов: \nБухгалтерского баланса (форма №1) и Отчета о прибылях и убытках (форма №2) на последнюю отчетную
#  дату либо на дату, на которую необходима оценка (при ретроспективном исследовании)\nАналитической информации об активах
#  и пассивах организации по состоянию на дату оценки: перечень основных средств, нематериальных активов и финансовых
#  вложений, расшифровка имеющихся запасов и материалов, незавершенного строительства, состав дебиторской и кредиторской
#  задолженности, информация о полученных кредитах. \nПосле анализа предоставленных документов формируется окончательный
#  перечень необходимой информации.' metadata={'Header 1': 'Оценка бизнеса [
#  https://federallab.ru/uslugi-ekspertizyi/oczenochnaya-ekspertiza/oczenka-biznesa/ ]'}
# ====================
#
# Chank#18/215. Tokens in text = 830
# --------------------
#  page_content='Chank#18/215. Оценка бизнеса. Оценка бизнеса: инструмент для успешных решений. \nОценка бизнеса - это
#  процесс определения стоимости предприятия, компании или активов в целом. Эта услуга является неотъемлемой частью
#  стратегического планирования и принятия важных решений в сфере бизнеса. Оценка бизнеса предоставляет собственникам и
#  управляющим знания и данные, которые помогают принимать обоснованные и эффективные решения в отношении компании.
#  \nВажным аспектом оценки бизнеса является определение финансовой стоимости компании на основе факторов, таких как
#  финансовые показатели, стратегии роста и конкурентоспособности, анализ отрасли, рыночные условия и многое другое.
#  Оценка бизнеса также может включать оценку физических активов, интеллектуальной собственности и бренда. \nОдной из
#  главных причин, по которым предприниматели обращаются к услугам оценки бизнеса, является продажа или приобретение
#  компании. При продаже бизнеса оценка помогает определить рыночную стоимость компании, на какую цену можно рассчитывать.
#  Это позволяет продавцу обоснованно устанавливать цену и привлекать потенциальных покупателей. При покупке бизнеса
#  оценка помогает определить, является ли предлагаемая цена справедливой и соответствует ли она реальной стоимости
#  компании. \nОценка бизнеса также может быть полезна при привлечении инвестиций, партнерских соглашениях, определении
#  стоимости привлекаемых капиталов, а также при разрешении конфликтных ситуаций внутри компании, связанных с долевым
#  участием и распределением активов. \nДля проведения оценки бизнеса может быть привлечено специальное агентство или
#  эксперт, обладающий необходимыми знаниями и опытом в данной области. Они проведут анализ финансовых данных, рыночных
#  условий, конкурентной среды и других факторов, необходимых для определения стоимости бизнеса. Результаты оценки
#  представляются в виде подробного отчета, который становится основанием для принятия решений.' metadata={'Header 1':
#  'Оценка бизнеса [ https://federallab.ru/uslugi-ekspertizyi/oczenochnaya-ekspertiza/oczenka-biznesa/ ]', 'Header 2':
#  'Оценка бизнеса: инструмент для успешных решений'}
# ====================
#
# Chank#19/215. Tokens in text = 438
# --------------------
#  page_content='Chank#19/215. Оценка бизнеса. Оценка бизнеса: инструмент для успешных решений. Ключевыми преимуществами
#  услуги оценки бизнеса являются:. \nОбъективная оценка стоимости компании, основанная на конкретных данных и
#  факторах.\nПомощь в принятии обоснованных решений в отношении компании и ее развития.\nЗащита интересов предпринимателя
#  при сделках покупки или продажи бизнеса.\nВозможность привлечения инвестиций и согласования партнерских соглашений на
#  более выгодных условиях.\nРазрешение внутренних конфликтов, связанных с распределением активов и долевым участием
#  сотрудников или партнеров. \nУслуга оценки бизнеса является важным инструментом для принятия решений в сфере
#  управления. Она помогает определить стоимость компании, основываясь на объективных данных и факторах, и принимать
#  обоснованные решения в отношении ее развития и возможных сделок. Оценка бизнеса способствует устойчивому росту и
#  успешному функционированию компании в динамичной и конкурентной бизнес-среде.' metadata={'Header 1': 'Оценка бизнеса [
#  https://federallab.ru/uslugi-ekspertizyi/oczenochnaya-ekspertiza/oczenka-biznesa/ ]', 'Header 2': 'Оценка бизнеса:
#  инструмент для успешных решений', 'Header 3': 'Ключевыми преимуществами услуги оценки бизнеса являются:'}
# ====================
#
# Chank#20/215. Tokens in text = 932
# --------------------
#  page_content='Chank#20/215. Оценка бизнеса: инструмент для успешных решений. Оценка стоимости бизнеса независимым
#  экспертом. \nОценка бизнеса независимым экспертом является важным инструментом для оценки стоимости предприятия, его
#  активов и потенциала. Бизнес-оценка проводится с целью определения финансовой ценности компании, а также для принятия
#  решений о продаже, покупке или участии инвесторов в предприятии. \nОценка бизнеса является сложным процессом, который
#  требует глубокого понимания основных финансовых показателей, факторов риска, макроэкономической обстановки и отраслевых
#  трендов. Чтобы получить объективный и независимый анализ, компании часто обращаются к независимым экспертам или
#  специализированным оценочным фирмам. \nПри проведении оценки бизнеса независимый эксперт анализирует различные аспекты
#  компании, включая ее финансовое состояние, уровень доходности, активы, долги и другие факторы. Оценка может
#  основываться на различных подходах и методах, включая сравнительный анализ, дисконтированные денежные потоки или
#  рыночные методы. \nОдним из ключевых компонентов оценки является анализ финансовой отчетности компании. Это включает
#  анализ доходов, расходов, активов и обязательств, а также оценку факторов риска, влияющих на финансовые результаты и
#  перспективы предприятия. \nОценка бизнеса также может включать анализ отраслевой среды и оценку конкурентного положения
#  компании. Это помогает понять, насколько успешно предприятие функционирует в своей сфере и какие возможности имеются
#  для дальнейшего роста и развития. \nНезависимые эксперты также могут учитывать факторы, которые не отражены в
#  финансовых отчетах, но могут иметь значительное влияние на стоимость компании. Например, репутация бренда, уровень
#  клиентской базы, интеллектуальная собственность или управленческий потенциал. \nОценка бизнеса независимыми экспертами
#  является важным инструментом для принятия обоснованных решений в сфере финансов и инвестиций. Она обеспечивает
#  объективность и независимость оценки, что позволяет компаниям и инвесторам принимать решения на основе реальной
#  стоимости бизнеса.' metadata={'Header 1': 'Оценка бизнеса [
#  https://federallab.ru/uslugi-ekspertizyi/oczenochnaya-ekspertiza/oczenka-biznesa/ ]', 'Header 2': 'Оценка бизнеса:
#  инструмент для успешных решений', 'Header 3': 'Оценка стоимости бизнеса независимым экспертом'}
# ====================
#
# Chank#21/215. Tokens in text = 201
# --------------------
#  page_content='Chank#21/215. Независимая автотехническая экспертиза. \nВ сложных ситуациях, связанных с
#  дорожно-транспортными происшествиями, или при купле-продаже автомобилей часто требуется профессиональная
#  автотехническая экспертиза. Специалисты ФЛСЭ по услуге независимая экспертиза авто в Самаре помогут разрешить спорные
#  вопросы путем проведения оценки состояния автомобиля и работ, необходимых для его восстановления после участия в ДТП.'
#  metadata={'Header 1': 'Независимая автотехническая экспертиза [
#  https://federallab.ru/uslugi-ekspertizyi/avtotexnicheskaya-ekspertiza/ ]'}
# ====================
#
# Chank#22/215. Tokens in text = 141
# --------------------
#  page_content='Chank#22/215. Независимая автотехническая экспертиза. Зачем нужна экспертиза и оценка ущерба после ДТП.
#  \nОпределить техническое состояние транспортного средства \nУстановить механизм, обстоятельства и этапы ДТП
#  \nОпределить соответствие действий водителей ПДД \nИзучить причины и условия ДТП' metadata={'Header 1': 'Независимая
#  автотехническая экспертиза [ https://federallab.ru/uslugi-ekspertizyi/avtotexnicheskaya-ekspertiza/ ]', 'Header 2':
#  'Зачем нужна экспертиза и оценка ущерба после ДТП'}
# ====================
#
# Chank#23/215. Tokens in text = 267
# --------------------
#  page_content='Chank#23/215. Независимая автотехническая экспертиза. Зачем нужна экспертиза и оценка ущерба после ДТП.
#  На какие вопросы отвечает независимая экспертиза авто в Самаре?. \nС какой скоростью двигались ТС?\nСостояние ТС до и
#  после столкновения\nТехнические причины ДТП\nРасположение на проезжей части\nПогодные условия\nСостояние водителя во
#  время ДТП\nСкорость движения ТС перед торможением\nБыла ли у водителя возможность избежать ДТП?\nБыла ли авария вызвана
#  неисправностью в работе автомобиля?\nТормозной путь \nИ еще многие другие вопросы автоэкспертизы' metadata={'Header 1':
#  'Независимая автотехническая экспертиза [ https://federallab.ru/uslugi-ekspertizyi/avtotexnicheskaya-ekspertiza/ ]',
#  'Header 2': 'Зачем нужна экспертиза и оценка ущерба после ДТП', 'Header 3': 'На какие вопросы отвечает независимая
#  экспертиза авто в Самаре?'}
# ====================
#
# Chank#24/215. Tokens in text = 311
# --------------------
#  page_content='Chank#24/215. Независимая автотехническая экспертиза. Зачем нужна экспертиза и оценка ущерба после ДТП.
#  Какие документы потребуются для автоэкспертизы в Самаре?. \nОбъяснения участников ДТП\nСхема ДТП, составленная
#  сотрудником ГИБДД, либо собственноручно составленная схема с расположением ТС в момент столкновения.\nСправка о
#  ДТП\nПостановление или протокол ГИБДД\nФото, поврежденного ТС или возможность предоставить авто на осмотр.\nЕсли есть,
#  фото с места ДТП, фото препятствия, если заявляется наезд на препятствие (либо описание препятствия водителем)\nЕсли
#  есть, дополнительные материалы (записи с видео-регистраторов, фото свидетелей и т.п.)' metadata={'Header 1':
#  'Независимая автотехническая экспертиза [ https://federallab.ru/uslugi-ekspertizyi/avtotexnicheskaya-ekspertiza/ ]',
#  'Header 2': 'Зачем нужна экспертиза и оценка ущерба после ДТП', 'Header 3': 'Какие документы потребуются для
#  автоэкспертизы в Самаре?'}
# ====================
#
# Chank#25/215. Tokens in text = 602
# --------------------
#  page_content='Chank#25/215. Экспертиза проектов. \nМы проводим экспертизу проектной документации, кроме случаев,
#  предусмотренных законодательством. Потребность возникает в спорах между заказчиком такого проекта, исполнителем
#  (проектантом), строителем, в случаях, когда выясняют, на каком этапе возникла ошибка, кто и какой объем должен сделать
#  по договору, а какой не должен и т.п. \nДля выявления реального соответствия фактов, занесенных в официальную
#  документацию, назначают проведение государственной или негосударственной экспертизы проектной документации зданий,
#  сооружений, технических комплексов. В результате исследования может быть обнаружен факт несоответствия, который грозит
#  опасностью для окружающей среды и людей.\nЕсли на данный момент вы желаете заняться активным строительством на
#  конкретном участке жилой или нежилой площади, необходимо пройти обязательную процедуру исследования результатов для
#  понимания соответствия всем заявленным государственным требованиям и безопасности. Если проигнорировать данный пункт,
#  строительство на объекте или реконструкция будут незаконны, а значит, их результат подлежит сносу.\nПри получении
#  отрицательных показателей застройщик не имеет права приступать к строительству и выполнять план по реконструкции
#  сооружения ввиду того, что проектная документация имеет расхождения с реальными фактами. Инициатор сам вправе решить, в
#  какую структуру обратиться за помощью в проведении независимой экспертизы проектной документации.' metadata={'Header
#  1': 'Экспертиза проектов [ https://federallab.ru/uslugi-ekspertizyi/ekspertiza-proektov/ ]'}
# ====================
#
# Chank#26/215. Tokens in text = 547
# --------------------
#  page_content='Chank#26/215. Экспертиза проектов. Преимущества независимой экспертизы. \nВозможность вести диалог с
#  персональным менеджером и вносить правки в проект;\nСтоимость услуги\xa0и цены часто на порядок ниже, чем в
#  государственных организациях;\nОперативное выполнение оценки. \nПрежде чем отправить официальный запрос на проведение
#  проверки, есть\xa0смысл передать на проверку всю сопровождающую документацию. Это поможет ускорить сроки проведения
#  экспертной оценки и повлияет на итоговый результат. \nВ большинстве случаев экспертиза является обязательным пунктом.
#  Во-вторых, это хорошая страховка для застройщика. Ведь в процессе проверки можно выявить все несоответствия и уберечь
#  себя от возможных рисков и вынужденных переплат исполняющим службам. В ходе проверки выясняются факты соответствия
#  инженерным условиям и нужному уровню безопасности для сотрудников, которые непосредственно имеют отношение к
#  строительству или реконструкции. \nОдним из преимуществ можно считать коррекцию планируемого бюджета на застройку,
#  реконструкцию. В ходе проверки можно идентифицировать перерасход планируемых финансовых вложений и перераспределить
#  средства на нужные статьи затрат. Срок выполнения экспертного анализа устанавливается в индивидуальном режиме, все
#  зависит от сложности и спецификации объекта.' metadata={'Header 1': 'Экспертиза проектов [
#  https://federallab.ru/uslugi-ekspertizyi/ekspertiza-proektov/ ]', 'Header 2': 'Преимущества независимой экспертизы'}
# ====================
#
# Chank#27/215. Tokens in text = 190
# --------------------
#  page_content='Chank#27/215. Налоговая экспертиза. \nНалоговая экспертиза – совокупность работ, направленных на анализ
#  финансовой деятельности предприятия. Целями проводимых работ являются выявление ошибок, минимизация рисков и
#  предупреждение проблем, связанных с налоговыми начислениями и выплатами. Во время проверки эксперт определяет, нет ли
#  нарушений деятельности предприятия, соответствует ли используемая система налоговых выплат действующему
#  законодательству РФ.' metadata={'Header 1': 'Налоговая экспертиза [
#  https://federallab.ru/uslugi-ekspertizyi/nalogovaya-ekspertiza/ ]'}
# ====================
#
# Chank#28/215. Tokens in text = 237
# --------------------
#  page_content='Chank#28/215. Налоговая экспертиза. Когда необходимо проводить налоговую экспертизу?. \nНалоговая
#  экспертиза является неотъемлемой частью эффективной налоговой практики и может потребоваться во многих ситуациях.
#  Обращение к эксперту и проведение налоговой экспертизы необходимы, когда требуется: \nоценка структуры налогов, которые
#  подлежат уплате;\nанализ используемой предприятием системы налогообложения, соответствия выбранной схемы действующему
#  законодательству;\nразработка модели уплаты налогов, оптимизации финансовой деятельности.' metadata={'Header 1':
#  'Налоговая экспертиза [ https://federallab.ru/uslugi-ekspertizyi/nalogovaya-ekspertiza/ ]', 'Header 2': 'Когда
#  необходимо проводить налоговую экспертизу?'}
# ====================
#
# Chank#29/215. Tokens in text = 430
# --------------------
#  page_content='Chank#29/215. Налоговая экспертиза. Задачи налоговой экспертизы. \nЦель проведения экспертизы состоит в
#  определении обязательств по налогам, подлежащих уплате налогоплательщиком. Эксперты также проверяют правильность
#  применения льгот и скидок по уплате налогов, анализируют декларации по налогам и предоставленные документы, чтобы
#  выявить возможные риски. \nОсновные задачи экспертизы, которые должны быть решены в ходе выполнения работ, включают в
#  себя: \nоперативную проверку депозитов, счетов, задолженностей предприятия;\nанализ используемой налоговой схемы и ее
#  соответствия действующему законодательству, проверку уплаченных сумм налогов;\nзащиту компании, ИП, организации от
#  незаконных действий налоговых органов;\nвыполнение проверки при объявлении компании себя банкротом;\nвыявление фактов
#  нарушений при расчетах и уплате сборов или налогов. \nВ результате экспертизы разрабатываются рекомендации по
#  устранению выявленных рисков и оптимизации налоговых обязательств.' metadata={'Header 1': 'Налоговая экспертиза [
#  https://federallab.ru/uslugi-ekspertizyi/nalogovaya-ekspertiza/ ]', 'Header 2': 'Задачи налоговой экспертизы'}
# ====================
#
# Chank#30/215. Tokens in text = 298
# --------------------
#  page_content='Chank#30/215. Налоговая экспертиза. Объекты налоговой экспертизы. \nЭксперты анализируют не только уплату
#  основных налогов (налог на добавленную стоимость, налог на прибыль, налог на имущество и т.д.), но и уплату пеней,
#  штрафов и иных санкций, связанных с налоговыми нарушениями. Поэтому к объектам данной экспертизы относят:
#  \nбухгалтерскую документацию и отчетность;\nакты о проведенных ранее проверках;\nналоговые декларации;\nбухгалтерские
#  регистры;\nпервичную бухгалтерская документация;\nавансовые документы, где обозначены точные суммы и даты
#  платежей;\nиные документы, касающиеся финансовой, инвестиционной деятельности предприятия.' metadata={'Header 1':
#  'Налоговая экспертиза [ https://federallab.ru/uslugi-ekspertizyi/nalogovaya-ekspertiza/ ]', 'Header 2': 'Объекты
#  налоговой экспертизы'}
# ====================
#
# Chank#31/215. Tokens in text = 461
# --------------------
#  page_content='Chank#31/215. Налоговая экспертиза. Направления налоговой экспертизы. \nПроводимая экспертная оценка
#  может включать в себя два направления – досудебную и судебную. В каждом отдельном случае требуется предварительный
# ...
#  автобусы 5600, при судебной экспертизе: Легковые а/м 12000 Грузовые а/м и автобусы 13000' metadata={'Header 1': 'Расчет
#  стоимости ремонта автотранспортного средства, подготовка заключения', 'Header 2': 'Расчет стоимости ремонта
#  транспортного средства по готовому акту осмотра, при включении в акт осмотра (повреждений) от 21 до 30 позиций'}
# ====================
#
# Chank#195/215. Tokens in text = 153
# --------------------
#  page_content='Chank#195/215. Расчет стоимости ремонта транспортного средства по готовому акту осмотра, при включении в
#  акт осмотра (повреждений) от 31 до 40 позиций, в рублях: при досудебной экспертизе Легковые а/м 4850 Грузовые а/м и
#  автобусы 6150, при судебной экспертизе: Легковые а/м 14000 Грузовые а/м и автобусы 15000' metadata={'Header 1': 'Расчет
#  стоимости ремонта автотранспортного средства, подготовка заключения', 'Header 2': 'Расчет стоимости ремонта
#  транспортного средства по готовому акту осмотра, при включении в акт осмотра (повреждений) от 31 до 40 позиций'}
# ====================
#
# Chank#196/215. Tokens in text = 153
# --------------------
#  page_content='Chank#196/215. Расчет стоимости ремонта транспортного средства по готовому акту осмотра, при включении в
#  акт осмотра (повреждений) от 41 до 50 позиций, в рублях: при досудебной экспертизе Легковые а/м 5600 Грузовые а/м и
#  автобусы 7250, при судебной экспертизе: Легковые а/м 15000 Грузовые а/м и автобусы 16000' metadata={'Header 1': 'Расчет
#  стоимости ремонта автотранспортного средства, подготовка заключения', 'Header 2': 'Расчет стоимости ремонта
#  транспортного средства по готовому акту осмотра, при включении в акт осмотра (повреждений) от 41 до 50 позиций'}
# ====================
#
# Chank#197/215. Tokens in text = 153
# --------------------
#  page_content='Chank#197/215. Расчет стоимости ремонта транспортного средства по готовому акту осмотра, при включении в
#  акт осмотра (повреждений) от 51 до 60 позиций, в рублях: при досудебной экспертизе Легковые а/м 6150 Грузовые а/м и
#  автобусы 8250, при судебной экспертизе: Легковые а/м 15000 Грузовые а/м и автобусы 16000' metadata={'Header 1': 'Расчет
#  стоимости ремонта автотранспортного средства, подготовка заключения', 'Header 2': 'Расчет стоимости ремонта
#  транспортного средства по готовому акту осмотра, при включении в акт осмотра (повреждений) от 51 до 60 позиций'}
# ====================
#
# Chank#198/215. Tokens in text = 149
# --------------------
#  page_content='Chank#198/215. Расчет стоимости ремонта транспортного средства по готовому акту осмотра, при включении в
#  акт осмотра (повреждений) от 61 позиции, в рублях: при досудебной экспертизе Легковые а/м 6950 Грузовые а/м и автобусы
#  9100, при судебной экспертизе: Легковые а/м 17000 Грузовые а/м и автобусы 18000' metadata={'Header 1': 'Расчет
#  стоимости ремонта автотранспортного средства, подготовка заключения', 'Header 2': 'Расчет стоимости ремонта
#  транспортного средства по готовому акту осмотра, при включении в акт осмотра (повреждений) от 61 позиции'}
# ====================
#
# Chank#199/215. Tokens in text = 124
# --------------------
#  page_content='Chank#199/215. Определение величины утраты товарной стоимости (без расчета стоимости ремонта) , руб. при
#  досудебной экспертизе Легковые а/м 3000 Грузовые а/м и автобусы 3650, при судебной экспертизе: Легковые а/м 6000
#  Грузовые а/м и автобусы 8000' metadata={'Header 1': 'Расчет стоимости ремонта автотранспортного средства, подготовка
#  заключения', 'Header 2': 'Определение величины утраты товарной стоимости (без расчета стоимости ремонта)'}
# ====================
#
# Chank#200/215. Tokens in text = 112
# --------------------
#  page_content='Chank#200/215. Определение рыночной стоимости транспортных средств, руб. при досудебной экспертизе
#  Легковые а/м 4300 Грузовые а/м и автобусы 5500, при судебной экспертизе: Легковые а/м 6000 Грузовые а/м и автобусы
#  7000' metadata={'Header 1': 'Расчет стоимости ремонта автотранспортного средства, подготовка заключения', 'Header 2':
#  'Определение рыночной стоимости транспортных средств'}
# ====================
#
# Chank#201/215. Tokens in text = 167
# --------------------
#  page_content='Chank#201/215. Составление акта разногласий по калькуляциям (счетам) других организаций (по готовому
#  расчету), экспертиза по нескольким актам осмотра , руб. при досудебной экспертизе Легковые а/м 1500 Грузовые а/м и
#  автобусы 2000, при судебной экспертизе: из расчета акта по наибольшему или совокупному количеству повреждений с
#  коэффициентом 1,5' metadata={'Header 1': 'Расчет стоимости ремонта автотранспортного средства, подготовка заключения',
#  'Header 2': 'Составление акта разногласий по калькуляциям (счетам) других организаций'}
# ====================
#
# Chank#202/215. Tokens in text = 106
# --------------------
#  page_content='Chank#202/215. Расчет стоимости годных остатков, руб. при досудебной экспертизе Легковые а/м 3000
#  Грузовые а/м и автобусы 3500, при судебной экспертизе: Легковые а/м от 6000 Грузовые а/м и автобусы от 7000'
#  metadata={'Header 1': 'Расчет стоимости ремонта автотранспортного средства, подготовка заключения', 'Header 2': 'Расчет
#  стоимости годных остатков'}
# ====================
#
# Chank#203/215. Tokens in text = 37
# --------------------
#  page_content='Chank#203/215. Проверка счетов СТО (без оформления акта разногласий) 700 руб.' metadata={'Header 1':
#  'Расчет стоимости ремонта автотранспортного средства, подготовка заключения', 'Header 2': 'Проверка счетов СТО'}
# ====================
#
# Chank#204/215. Tokens in text = 168
# --------------------
#  page_content='Chank#204/215. Выезд эксперта для осмотра объекта (транспорт исполнителя), в пределах г. Самара, 1 час,
#  оплачивается не менее 2 часов - 750 руб.\nВыезд эксперта для осмотра объекта (транспорт исполнителя), за пределы
#  Самары, 20 руб./км\nВыезд эксперта в суд, первые 2 часа -3700 руб. Свыше 2-х часов - 1500 руб./час. Первое заседание не
#  оплачивается.' metadata={'Header 1': 'Расчет стоимости ремонта автотранспортного средства, подготовка заключения',
#  'Header 2': 'Выезд эксперта для осмотра объекта'}
# ====================
#
# Chank#205/215. Tokens in text = 42
# --------------------
#  page_content='Chank#205/215. Копия отчета (Заключения) 700 руб, при согласовании с судом 1000 руб.' metadata={'Header
#  1': 'Расчет стоимости ремонта автотранспортного средства, подготовка заключения', 'Header 2': 'Копия отчета
#  (Заключения)'}
# ====================
#
# Chank#206/215. Tokens in text = 17
# --------------------
#  page_content='Chank#206/215. Телеграмма 600 руб.' metadata={'Header 1': 'Расчет стоимости ремонта автотранспортного
#  средства, подготовка заключения', 'Header 2': 'Телеграмма'}
# ====================
#
# Chank#207/215. Tokens in text = 24
# --------------------
#  page_content='Chank#207/215. Оценка для нотариуса 2000 руб.' metadata={'Header 1': 'Расчет стоимости ремонта
#  автотранспортного средства, подготовка заключения', 'Header 2': 'Оценка для нотариуса'}
# ====================
#
# Chank#208/215. Tokens in text = 35
# --------------------
#  page_content='Chank#208/215. Письменная справка о средней рыночной стоимости 2000 руб.' metadata={'Header 1': 'Расчет
#  стоимости ремонта автотранспортного средства, подготовка заключения', 'Header 2': 'Письменная справка о средней
#  рыночной стоимости'}
# ====================
#
# Chank#209/215. Tokens in text = 394
# --------------------
#  page_content='Chank#209/215. Адвокат коллегии «Адвокатов №1» города Самары. Я работаю адвокатом более 36 лет. За
#  это\nвремя у меня возникали много раз случаи, когда было необходимо к участию в рассмотрении дела\nпривлекать
#  экспертов. В связи с этим я обращался в различные экспертные учреждения, но в последнее\nвремя я обращаюсь в
#  Федеральную лабораторию судебных экспертиз, поскольку эксперты в этом\nучреждении довольно грамотные. Экспертизы делают
#  быстро, качественно и по демократичным ценам.\nКроме того, заключения экспертов этого экспертного учреждения всегда
#  принимаются судами,\nкак исполнены в соответствии с требованиями закона и не вызывают нареканий. В связи с этим я
#  сам\nобращаюсь за консультациями к экспертам в этом экспертном учреждении, а также рекомендую своим\nколлегам в случае
#  необходимости также обращаться именно в это экспертное учреждение.' metadata={'Header 1': 'Отзыв 1'}
# ====================
#
# Chank#210/215. Tokens in text = 530
# --------------------
#  page_content='Chank#210/215. Я являюсь правляющим партнером Адвокатского бюро «Яблоко и партнеры». Под моим
#  началом\nработает 10 адвокатов, и каждый из них в своей деятельности постоянно сталкивается с\nнеобходимостью
#  привлечения специалистов, обладающих глубокими познаниями в той или иной отрасли.\nИ мы постоянно сотрудничаем с
#  Федеральной лабораторией судебный экспертиз, возглавляемой\nЕленой Зубковой. Нам очень нравится качество работы
#  специалистов. Нам нравится не только\nквалификация специалистов, которые там работают, и готовность помочь в
#  составлении подготовки\nвопросов, объяснить в какой ситуации те или иные вопросы лучше не ставить, но еще и
#  готовность\nзащитить те выводы, к которым эксперты пришли в рамках судебного заседания. Грамотно,\nчетко и
#  квалифицированно ответить не только на наши вопросы, но и на вопросы противоположной\nстраны. Строительно-техническая
#  экспертиза, почерковеческая экспертиза, оценка рыночной\nстоимости доли предприятий или объектов недвижимости — это те
#  вопросы, по которым мы\nпостоянно обращаемся в Федеральную лабораторию судебной экспертизы, и можем другим коллегам\nи
#  адвокатам рекомендовать туда обращаться.' metadata={'Header 1': 'Отзыв 2'}
# ====================
#
# Chank#211/215. Tokens in text = 430
# --------------------
#  page_content='Chank#211/215. Меня зовут Елена Зубкова, я основатель и руководитель федеральной лаборатории судебной
#  экспертизы.\nА наши эксперты, одни из лучших в регионе.\nЗа шесть лет существования мы произвели четыре тысячи судебных
#  экспертиз и ежемесячно производим не менее семидесяти исследований.\nПочерковические, автотехнические,
#  трассологические, товароведческие,землеустроительные, строительно-технические, бухгалтерские,оценочные.\nВсе эти виды
#  экспертизы мы производим силами собственных штатных экспертов.\nБлагодаря отлаженным бизнес-процессам и современному
#  парку оборудования мы сократили время производства экспертиз в два раза и уже через два дня вы можете забрать готовое
#  исследование.\nВы предоставляете документы, производите оплату любым удобным способом – наличными, банковской картой,
#  переводом на расчетный счет.\nПри возникновении затруднений мы поможем вам собрать необходимую информацию и
#  сформулировать вопрос к эксперту.' metadata={'Header 1': 'О компании', 'Header 2': 'Услуги компании'}
# ====================
#
# Chank#212/215. Tokens in text = 657
# --------------------
#  page_content='Chank#212/215. Преимущества компании и ее клиенты\nНаши технологии позволяют решить ряд проблем,
#  возникающих при обращении.\nНапример, некорректная постановка вопросов к эксперту, неспособная разрешить проблему,
#  длительный период ожидания ответа на запрос для судебного заседания, длительный срок производства экспертизы и
#  недостоверность экспертного заключения.\nБесплатная консультация с экспертом напрямую, слаженная работа менеджеров,
#  несколько каналов для приема заявок, современное оборудование, достаточный штат экспертов, продуманная логистика,
#  высокий профессионализм и опыт работы сотрудников, внутрифирменный контроль качества, двухуровневая проверка
#  заключений.\nОб этих и других проблемах давно забыли наши клиенты.\nНапример, адвокатское бюро, яблоков и партнеры.
#  \nФедеральная лаборатория судебной экспертизы на рынке с 2013 года и среди тех, с кем мы работаем.\nОсобая
#  экономическая зона города Тольятти, Корпорация развития Самарской области, Самарский речной порт, Управление ФНС по
#  Самарской области, Тольятти Хлеб, ООС Сименс Финанс, Корпорация Роснефть, Кока-Кола, Башнефть, Газпромбанк, Сбербанк и
#  другие.\nГеография нашей работы не ограничивается территорией Самарской области, арбитражными судами и судами общей
#  юрисдикции.\nВ числе клиентов арбитражный суд Павловского округа, арбитражные суды Калужской, Ульяновской,
#  Московской,Оренбургской и Псковской областей, Республики Татарстан.' metadata={'Header 1': 'О компании', 'Header 2': 'В
#  чем наше преимущество'}
# ====================
#
# Chank#213/215. Tokens in text = 749
# --------------------
#  page_content='Chank#213/215. Адвокатская практика я занимаюсь с 2000 года. Наше бюро располагается в городе Самары.
#  На\nсамом деле география работы, география практики распространяется на территории всей Российской\nФедерации и мы
#  оказываем юридическую помощь клиентам на территории всех субъектов Российской\nФедерации и в том числе за рубежом. Наше
#  адвокатское бюро специализируется на юридической\nпомощи бизнесу и в связи с этим у нас очень много арбитражных споров,
#  судов и споров в судах\nобщей юридикции. И как мы знаем экспертиза это одно из основных доказательств,
#  которые\nиспользуются странами и в нашей практике мы очень часто обращаемся к экспертам за помощью. Но\nпо моим
#  наблюдениям очень много экспертиз судебных строительных, бухгалтерских, подчерковедческих\nбезусловно. И мы очень рады,
#  что сотрудничаем с Федеральной лабораторией судебных экспертиз,\nпоскольку они показывают максимальную компетентность и
#  качественность работы.\nНу могу сказать следующее, что с нашей стороны, со своей стороны мы рассматриваем
#  Федеральную\nлабораторию судебных экспертиз как надежного и хорошего партнера, с которым мы рассчитываем,\nчто будем
#  сотрудничать и в дальнейшем. И со своей стороны могу только рекомендовать\nсотрудничать с данной организацией. Вы
#  знаете Сарафанное радио, это наверное один из лучших\nисточников продвижения. На него нужно ориентироваться, когда вы
#  выбираете того или иного\nисполнителя услуг. Вот можете поверить, что я надеюсь с своей стороны передал по этому
#  Сарафаннову\nрадио свое сообщение о том, что этот партнер является надежным.\nСпасибо за субтитры Алексею Дубровскому!'
#  metadata={'Header 1': 'О компании', 'Header 2': 'Отзыв 3'}
# ====================
#
# Chank#214/215. Tokens in text = 681
# --------------------
#  page_content='Chank#214/215. Для удобства наших клиентов мы готовы бесплатно консультировать по вопросам
#  целесообразности производства экспертизы, участвовать в формулировке вопросов к эксперту и помогать в поиске источников
#  необходимой информации.\nКак это работает?\nКлиент оставляет заявку на производство экспертизы любым удобным способом и
#  свои контактные данные.\nЭксперт соответствующей специальности связывается с клиентом и консультирует либо в режиме
#  онлайн, либо назначает время встречи для ознакомления с материалами.\nЗаказчик за это не платит.\nПри необходимости
#  дополнительно проводится очная консультация с изучением документов.\nЕсли предусмотрен досудебный порядок исследования,
#  то заключается договор.\nПри судебном рассмотрении спора подготавливается информационное письмо по результатам
#  рассмотрения обращения для назначения экспертизы судом.\nМы сами имеем возможность забирать назначенные экспертизы в
#  суде.\nЭто сокращает сроки работы.\nУведомления сторон производятся посредством специального программного комплекса за
#  рабочим местом, что позволяет всегда подтвердить факт соблюдения процессуальных прав и экономит общее время работы над
#  исследованием.\nЭлектронные справочники нормативной документации в свободном доступе у эксперта.\nЛюбой довод
#  подтвержден.\nФедеральная лаборатория – одна из немногих в своем сегменте, которая использует передовые
#  бизнес-технологии.\nНаши менеджеры всегда на связи.\nВесь бизнес-процесс прописан.\nВсе, что вам нужно – только назвать
#  параметры исследуемого объекта, и вы узнаете статус работы.\nОставьте заявку на бесплатную консультацию прямо сейчас, и
#  мы свяжемся с вами всего за 15 минут.' metadata={'Header 1': 'О компании', 'Header 2': 'Порядок работы с заказчиком'}
# ====================
#
# ====================
# Количество токенов в документе : 75229
# ЦЕНА запроса: 0.0075229  $
#
# Загрузка текстовой Базы знаний выполнена успешно.

# %%
#@title Архивирование Базы знаний (при необходимости).

# В дальнейшем архив нужно поместить на GitHub
archive = False
if archive:
    folder_to_zip = 'federallab_bd_index'
    output_filename = 'federallab_bd_index.zip'
    # Сохранение папки с векторной Базой знаний.
    federallab_bd_index.save_local(folder_to_zip)
    # Архивирование папки с векторной Базой знаний
    with zipfile.ZipFile(output_filename, 'w') as zip:
        for root, dirs, files in os.walk(folder_to_zip):
            for file in files:
                zip.write(os.path.join(root, file))

# %% [markdown]
# # Параметры запроса нейро-консультанту.

# %%
 # Параметры запроса нейро-консультанту.

# Данные по названиям модели и стоимости токена на 22.11.2023.
# https://openai.com/pricing#language-models
# Псевдоним = ['Имя модели', 'Цена токена - вопроса', 'Цена токена - ответа'].
MODEL_GPT_4_1106_PREVIEW = ['gpt-4-1106-preview', 0.01, 0.03]   # 128K tokens
MODEL_GPT_3_5_TURBO_1106 = ['gpt-3.5-turbo-1106', 0.001, 0.002] #  16K tokens

# Общие настройки для одиночного и группового запроса.
SELECT_MODEL_GPT = MODEL_GPT_3_5_TURBO_1106 # Выбранная модель.
top_documents = 3                           # Количество полученных релевантных чанков после запроса.
temp = 0                                    # Вариативность ответа.
#federallab_chat_promt = load_file("https://raw.githubusercontent.com/terrainternship/GPT_labsud/main/Dokumov/%D0%A2%D1%8B%20%D1%81%D0%B0%D0%BC%D1%8B%D0%B9%20%D0%BA%D0%BE%D0%BC%D0%BF%D0%B5%D1%82%D0%B5%D0%BD%D1%82%D0%BD%D1%8B%D0%B9%20%D0%BD%D0%B5%D0%B9%D1%80%D0%BE-%D0%BA%D0%BE%D0%BD%D1%81%D1%83%D0%BB%D1%8C.txt")
federallab_chat_promt = load_file("https://raw.githubusercontent.com/terrainternship/GPT_labsud/main/Galina/FLSE_promt")

# Настройки только для одиночного запроса.
verbose_documents = 1   # Показывать отобранные чанки.
verbose_price = 1       # Показывать стоимость запроса.

# %% [markdown]
# # Одиночный запрос.

# %%
#@title Вопрос нейро-консультанту:
question = 'Стоимость экспертизы технического состояния ТС?'

# %%
#@title Отправка вопроса нейро-консультанту.

answer = answer_index(
    model = SELECT_MODEL_GPT,
    system = federallab_chat_promt,
    topic = question,
    search_index = federallab_bd_index,
    temp = temp,
    verbose_documents = verbose_documents,
    verbose_price = verbose_price,
    top_documents = top_documents,
    query = '',
)

print()
print(f'ВОПРОС:\n{insert_newlines(question)}\n')
print(f'ОТВЕТ:\n{insert_newlines(answer)}')
# Out:
# Отрывок документа №1
# -----------------------
#  Chank#139. Товарная экспертиза. Экспертиза оборудования, ТС, пр. имущества в силу частичной или полной гибели для
#  списания Минимальная стоимость досудебного исследования в зависимости от количества: 1-3 ед. 3000 руб., 4-5 ед. 2500
#  руб., 6-10 ед. 2000 руб., 10-30 ед. 1750 руб., 30-50 ед.1500 руб. Стоимость судебной экспертизы в зависимости от
#  количества: 1-3 ед. 6000 руб., 4-5 ед. 5000 руб., 6-10 ед. 4000 руб., 10-30 ед. 3500 руб., 30-50 ед.3000 руб.
#  Минимальный срок проведения 5 - 10 дней
#
# Отрывок документа №2
# -----------------------
#  Chank#138. Товарная экспертиза. Экспертиза машин и механизмов, технологического оборудования, ТС, узлов и агрегатов при
#  экспертизе одного дефекта одной единицы Минимальная стоимость досудебного исследования 15 000 руб. Стоимость судебной
#  экспертизы 25 000 руб. при экспертизе до 3-х дефектов или до 3-х единиц Минимальная стоимость досудебного исследования
#  10 000 руб. Стоимость судебной экспертизы 15 000 руб. при экспертизе 4-5 дефектов или 4-5 единиц Минимальная стоимость
#  досудебного исследования 8 000 руб. Стоимость судебной экспертизы 12 000 руб Минимальный срок проведения 5 - 10 дней
#
# Отрывок документа №3
# -----------------------
#  Chank#9. Экспертиза технического состояния ТС. Какие элементы ТС могут быть подвергуты экспертизе технического
#  состояния ТС. В рамках экспертизы технического состояния ТС может быть проведена: экспертиза двигателя автомобиля и его
#  мощности; экспертиза кузова; экспертиза коробки передач; экспертиза подвески; экспертиза шасси; экспертиза бампера;
#  экспертиза приборов; экспертиза прочих узлов и агрегатов.
#
#
# =======================================================
# 1712 токенов использовано на вопрос. Цена: 0.001712 $.
# 130 токенов использовано на ответ.  Цена: 0.00026 $.
# 1842 токенов использовано всего.     Цена: 0.001972 $
# =======================================================
#
# ВОПРОС:
#  Стоимость экспертизы технического состояния ТС?
#
# ОТВЕТ:
#  Стоимость экспертизы технического состояния ТС зависит от количества элементов, которые подлежат экспертизе.
#  Минимальная стоимость досудебного исследования варьируется от 15 000 рублей до 3-х дефектов или до 3-х единиц, а
#  стоимость судебной экспертизы составляет 25 000 рублей.

# %% [markdown]
# # Групповой запрос.

# %%
auth.authenticate_user()        # Аутентифицируем текущего пользователя Colab
creds, _ = default()            # Создаем объект учетных данных на основе аутентификации
gc = gspread.authorize(creds)   # Создаем клиент для таблиц на основе учетных данных

# %%
# Название файла с вопросами.
# Ссылка на общий файл.
try:
    spreadsheet = gc.open_by_url('https://docs.google.com/spreadsheets/d/1p69Ma_vcEU86_lde61l5RtawJIbGwpAhpXHo2DEKNDo/edit#gid=1834702311')
    print(f'Подключились к документу - {spreadsheet.title}')
except Exception as e:
    print(e)
    print(f'Ошибка подключения к документу. Проверьте ссылку.')
# Out:
# Подключились к документу - FederalLab

# %%
# Получаем список всех страниц файла.
worksheet_list = spreadsheet.worksheets()
print('Страницы документа:')
print('-------------------')
for i, worksheet in enumerate(worksheet_list):
        print(f'  {i}. {worksheet.title}')
# Out:
# Страницы документа:
# -------------------
#   0. Инструкции
#   1. Страницы
#   2. Исключенные
#   3. Шаблон
#   4. Докумов
#   5. Макеев
#   6. Галина
#   7. Петрунин
#   8. Шляпников
#   9. Бугаев
#   10.  A.Куцинс

# %%
# Устанавливаем номер рабочего листа по списку выше.
number_sheet = 7 # Петрунин=7
#---------------------------------------------------
worksheet = worksheet_list[number_sheet]
# Проверка текущей страницы.
print(f'Текущая страница - "{worksheet.title}"\n')
# Список всех столбцов на странице.
print('-----№---------Название---')
for i, col in enumerate(worksheet.row_values(1)):
    print(f'Колонка № {i}. {col}')
# Out:
# Текущая страница - "Петрунин"
#
# -----№---------Название---
# Колонка № 0. Ответственный
# Колонка № 1. URL
# Колонка № 2. Название
# Колонка № 3. Вопрос
# Колонка № 4. Ожидаемый ответ
# Колонка № 5. Ответ GPT
# Колонка № 6. Оценка
# Колонка № 7. Ошибка
# Колонка № 8. Комментарий
# Колонка № 9. Чанк №1
# Колонка № 10. Чанк №2
# Колонка № 11. Чанк №3

# %%
""" В данном блоке происходит заполнение списка запросов вопросами и дополнительной
информацией с выбранного листа. Загрузка выполняется ВСЕХ строк с вопросами для
последующей корректной работы. Далее из этого списка выбирается нужный диапазон
вопросов для группового запроса к GPT."""

# Устанавливаем номер колонки с вопросами. Проверить со списком.
column_question = 3
#------------------
# Выбор всех вопросов.
column = worksheet.col_values(column_question)
# Создаем пустой список запросов.
list_query = []
# Заполнение списка запросов информацией с выбранного листа.
for i in range(len(column)-1):
    row = worksheet.row_values(i+2)
    # Считывание ячеек с контролем их наличия для избежании ошибки чтения.
    # Проверить индексы row со списком в ячейке выше.
    person = row[0] if len(row)>=1 else ""      # Автор вопроса.
    link = row[1] if len(row)>=2 else ""        # Ссылка на тему.
    subject = row[2] if len(row)>=3 else ""     # Тема вопроса.
    question = row[3] if len(row)>=4 else ""    # Вопрос.
    answer = row[4] if len(row)>=5 else ""      # Ожидаемый ответ.
    # Словарь запроса.
    query = {
        "line": i+2,            # Номер строки в документе. Берем строки с вопросами.
        "person": person,       # Автор вопроса.
        "subject": subject,     # Тема вопроса.
        "link": link,           # Ссылка на тему.
        "question": question,   # Вопрос.
        "answer": question,     # Ожидаемый ответ.
        "answer_gpt": "",       # Ответ GPT.
        "appraisal": None,      # Оценка ответа.
        "bug": "",              # Ошибка.
        "comments": "",         # Комментарии.
        "chank_1": "",          # Чанк №1.
        "chank_2": "",          # Чанк №2.
        "chank_3": "",          # Чанк №3.
        "price_query": 0,       # Стоимость запроса общая.
        "price_question": 0,    # Стоимость вопроса с контекстом.
        "price_answer": 0,      # Стоимость ответа.
        "token_query": 0,       # Количество токенов всего вопро-ответ.
        "token_question": 0,    # Количество токенов в вопросе с контекстом.
        "token_answer": 0,      # Количество токенов в ответе.
    }
    list_query.append(query)
print(f'Загрузка списка вопросов завершена. Количество вопросов: {len(column)-1}.')
# Out:
# Загрузка списка вопросов завершена. Количество вопросов: 60.

# %%
# Пример считанного первого запроса.
# Установкой среза можно вывести интересующий интервал.
for query in list_query[:1]:
    print(f'Строка №{query["line"]}. Вопрос: {query["question"]}')
    print(query)
# Out:
# Строка №2. Вопрос: Какие элементы ТС подвергаются экспертизе техничестого состоянияТС?
# {'line': 2, 'person': 'Петрунин', 'subject': 'Экспертиза технического состояния ТС', 'link': 'https://federallab.ru/uslugi-ekspertizyi/avtotexnicheskaya-ekspertiza/ekspertiza-texnicheskogo-sostoyaniya-ts/', 'question': 'Какие элементы ТС подвергаются экспертизе техничестого состоянияТС?', 'answer': 'Какие элементы ТС подвергаются экспертизе техничестого состоянияТС?', 'answer_gpt': '', 'appraisal': None, 'bug': '', 'comments': '', 'chank_1': '', 'chank_2': '', 'chank_3': '', 'price_query': 0, 'price_question': 0, 'price_answer': 0, 'token_query': 0, 'token_question': 0, 'token_answer': 0}

# %%
# Диапазон строк с вопросами на выбранной странице.
print(f"Диапазон номеров строк с вопросами (включительно): [{list_query[0]['line']}:{list_query[-1]['line']}].")
# Out:
# Диапазон номеров строк с вопросами (включительно): [2:61].

# %%
#@title Отправка группового запроса нейро-консультанту.
""" Если подвис ответ от GPT можно прервать обработку, установить row_first
в значение на которой была прервана обработка и запустить обработку заново.
Ранее обработанные вопросы будут сохранены в файле. """

# Определение диапазона строк с вопросами. Начало диапазона, конец диапазона.
row_first, row_end = 2, 2
# Обнуление общих затрат на групповой запрос.
total_price_query, total_token_query, total_query = 0, 0, 0
# Фиксация времени.
start_group = timeit.default_timer()

for query in list_query[row_first-2:row_end-1]:
    # Отправка запроса. Фиксация времени.
    start = timeit.default_timer()
    try:
        query["answer_gpt"]= answer_index(
            model = SELECT_MODEL_GPT,
            system = federallab_chat_promt,
            topic = "",
            search_index = federallab_bd_index,
            temp = temp,
            verbose_documents = 0,
            verbose_price = 0,
            top_documents = top_documents,
            query = query,
        )
        total_price_query += query['price_query']
        total_token_query += query['token_query']
        total_query +=1
    except Exception as e:
        print(f'Ошибка ответа GPT на строке №{query["line"]}. - {e}')
    end = timeit.default_timer()
    # Сообщение об успешности ответа от GPT.
    print(f'Строка №{query["line"]}. Ответ на вопрос получен за - {round(end-start, 3)} сек.')

    # Запись ответа в файл.
    try:
        if bool(query['answer_gpt']):
            worksheet.update_cell(query['line'], 6, query['answer_gpt']) # Ответ GPT.
            worksheet.update_cell(query['line'], 10, query['chank_1'])   # Чанк №1.
            worksheet.update_cell(query['line'], 11, query['chank_2'])   # Чанк №2.
            worksheet.update_cell(query['line'], 12, query['chank_3'])   # Чанк №3.
            print(f'Строка №{query["line"]}. Ответ записан в файл.')
    except Exception as e:
        print('\n========================================================')
        print(f'!!!Ошибка записи строки №{query["line"]} в файл. - {e}')
        print('========================================================')

end_group = timeit.default_timer()
print()
print('-------------------------------------------')
print(f'Вопросов в пакетной обработке - {total_query} шт.')
print(f'Время пакетной обработки      - {round(end_group-start_group, 1)} сек.')
print(f'Стоимость пакетной обработки  - {round(total_price_query, 4)} $.')
print(f'Токенов в пакетной обработке  - {total_token_query} шт.')
# Out:
# Строка №2. Ответ на вопрос получен за - 3.07 сек.
# Строка №2. Ответ записан в файл.
#
# -------------------------------------------
# Вопросов в пакетной обработке - 1 шт.
# Время пакетной обработки      - 4.5 сек.
# Стоимость пакетной обработки  - 0.0024 $.
# Токенов в пакетной обработке  - 2339 шт.

# %%
for i, query in enumerate(list_query):
    if query['answer_gpt']:
        print(insert_newlines(f"ВОПРОС №{i+2}: {query['question']}"))
        print('---------------------------')
        print(insert_newlines(f"ОТВЕТ: {query['answer_gpt']}"))
        print('===========================\n')
        print(query['chank_1'])
# Out:
#  ВОПРОС №2: Какие элементы ТС подвергаются экспертизе техничестого состоянияТС?
# ---------------------------
#  ОТВЕТ: Экспертиза технического состояния ТС может включать в себя экспертизу двигателя автомобиля и его мощности,
#  кузова, коробки передач, подвески, шасси, бампера, приборов, а также других узлов и агрегатов.
# ===========================
#
# Chank#9/215. Экспертиза технического состояния ТС. Какие элементы ТС могут быть подвергуты экспертизе технического состояния ТС.
# В рамках экспертизы технического состояния ТС может быть проведена:
# экспертиза двигателя автомобиля и его мощности;
# экспертиза кузова;
# экспертиза коробки передач;
# экспертиза подвески;
# экспертиза шасси;
# экспертиза бампера;
# экспертиза приборов;
# экспертиза прочих узлов и агрегатов..
# --------
# https://federallab.ru/uslugi-ekspertizyi/avtotexnicheskaya-ekspertiza/ekspertiza-texnicheskogo-sostoyaniya-ts/
