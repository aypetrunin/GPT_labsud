# %%
import os
os.chdir("..")

# %%
from parsing.tabletomd import table_do_md_class
m = table_do_md_class()
m.load()
#m.parse_t1()

# %%
#m.save(m.t1,"price.md")
m.parse_t2()
m.save(m.t2,"price2.md")

# %%
from gpt_openai.price_embeding import price_db

# %%
docs = price_db.db.similarity_search_with_score("Price. индивидуальные гаражи",k=3,)

# %%
#docs = db1.similarity_search_with_score("Экспертиза сотовых телефонов",k=10,)
docs

# %%
txt = "Почерковедческая экспертиза"
docs = db1.similarity_search_with_score("Экспертиза сотовых телефонов",k=3)
docs
# Out:
# [Document(page_content='Price. Товарная экспертиза\nЭкспертиза сотовых телефонов и электротехники, бытового оборудования и бытовой техники', metadata={'H1': 'Товарная экспертиза', 'H2': 'Экспертиза сотовых телефонов и электротехники, бытового оборудования и бытовой техники'}),
#  Document(page_content='Price. Товарная экспертиза\nЭкспертиза машин и механизмов, технологического оборудования, ТС, узлов и агрегатов', metadata={'H1': 'Товарная экспертиза', 'H2': 'Экспертиза машин и механизмов, технологического оборудования, ТС, узлов и агрегатов'}),
#  Document(page_content='Price. Товарная экспертиза\nЭкспертиза оборудования, ТС, пр. имущества в силу частичной или полной гибели для списания', metadata={'H1': 'Товарная экспертиза', 'H2': 'Экспертиза оборудования, ТС, пр. имущества в силу частичной или полной гибели для списания'})]

# %%
gpt.hist(fragments)

# %%
fragments[0].metadata
# Out:
# {'H1': 'Товарная экспертиза',
#  'H2': 'Экспертиза сотовых телефонов и электротехники, бытового оборудования и бытовой техники'}

# %%
from langchain.docstore.document import Document
def func(f:Document):
    h1 = f.metadata["H1"]
    h2 = f.metadata["H2"]
    # content =f.page_content
    d= Document(page_content=f"Price. {h1}\n{h2}",metadata=f.metadata)
    return d

price_fragments = [func(f)  for f in fragments]

# %%
gpt.hist(price_fragments)

# %%
from parsing.conf import config
os.path.dirname(config.data_path)
#config.data_path
# Out:
# 'c:/Data/Study/NU/Stag/py'

# %%
price_fragments
# Out:
# [Document(page_content='Price. Товарная экспертиза\nЭкспертиза сотовых телефонов и электротехники, бытового оборудования и бытовой техники', metadata={'H1': 'Товарная экспертиза', 'H2': 'Экспертиза сотовых телефонов и электротехники, бытового оборудования и бытовой техники'}),
#  Document(page_content='Price. Товарная экспертиза\nЭкспертиза машин и механизмов, технологического оборудования, ТС, узлов и агрегатов', metadata={'H1': 'Товарная экспертиза', 'H2': 'Экспертиза машин и механизмов, технологического оборудования, ТС, узлов и агрегатов'}),
#  Document(page_content='Price. Товарная экспертиза\nЭкспертиза оборудования, ТС, пр. имущества в силу частичной или полной гибели для списания', metadata={'H1': 'Товарная экспертиза', 'H2': 'Экспертиза оборудования, ТС, пр. имущества в силу частичной или полной гибели для списания'}),
# ...

# %%
from parsing.conf import config
config.OPENAI_API_KEY
os.environ["OPENAI_API_KEY"] = config.OPENAI_API_KEY

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
# Инициализирум модель эмбеддингов
embeddings = OpenAIEmbeddings()

# Создадим индексную базу из разделенных фрагментов текста
db = FAISS.from_documents(price_fragments, embeddings)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# c:\Data\Study\NU\Git14\py_stag_labsud\project\i\pricedb.ipynb Cell 10 line 7
#       <a href='vscode-notebook-cell:/c%3A/Data/Study/NU/Git14/py_stag_labsud/project/i/pricedb.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> embeddings = OpenAIEmbeddings()
#       <a href='vscode-notebook-cell:/c%3A/Data/Study/NU/Git14/py_stag_labsud/project/i/pricedb.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a> # Создадим индексную базу из разделенных фрагментов текста
# ----> <a href='vscode-notebook-cell:/c%3A/Data/Study/NU/Git14/py_stag_labsud/project/i/pricedb.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> db = FAISS.from_documents(price_fragments, embeddings)
#
# File c:\Data\Study\NU\Git14\py_stag_labsud\project\env\Lib\site-packages\langchain\schema\vectorstore.py:510, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
# ...
